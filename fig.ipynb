# %%
import matplotlib.pyplot as plt

# 方法名
methods = ['rem-atten', 'rem-near', 'rem-gru', 'all']

# 各种指标
precision = [0.911, 0.913, 0.934, 0.948]
recall = [0.842, 0.873, 0.871, 0.876]
f1_score = [0.875, 0.892, 0.901, 0.910]
avg = [0.876, 0.893, 0.902, 0.911]

# 绘图
plt.figure(figsize=(10, 6))
plt.plot(methods, precision, marker='o', label='Precision', color='blue')
plt.plot(methods, recall, marker='s', label='Recall', color='green')
plt.plot(methods, f1_score, marker='^', label='F1 Score', color='red')
plt.plot(methods, avg, marker='d', label='Avg', color='purple')

# 设置纵轴范围从0.8开始
plt.ylim(0.8, 1.0)

# 添加图例、标题和标签
plt.title('Ablation Study Results')
plt.xlabel('Method')
plt.ylabel('Score')
plt.grid(True)
plt.legend()
plt.tight_layout()


plt.savefig('Ablation_Study_Results.jpg',dpi=300, bbox_inches='tight')
# 显示图像
plt.show()

# %%
import matplotlib.pyplot as plt

# 方法名
methods = ['1_layer', '2_layer', '3_layer', '4_layer']

# 各种指标
precision = [0.921, 0.948, 0.929, 0.945]
recall = [0.866, 0.876, 0.877, 0.872]
f1_score = [0.892, 0.910, 0.902, 0.907]
avg = [0.893, 0.911, 0.903, 0.908]

# 绘图
plt.figure(figsize=(10, 6))
plt.plot(methods, precision, marker='o', label='Precision', color='blue')
plt.plot(methods, recall, marker='s', label='Recall', color='green')
plt.plot(methods, f1_score, marker='^', label='F1 Score', color='red')
plt.plot(methods, avg, marker='d', label='Avg', color='purple')

# 设置纵轴范围从0.8开始
plt.ylim(0.8, 1.0)

# 添加图例、标题和标签
plt.title('Ablation Study on Layer Depth')
plt.xlabel('Method')
plt.ylabel('Score')
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.savefig('Layer_Depth.jpg',dpi=300, bbox_inches='tight')
# 显示图像
plt.show()

# %%
import matplotlib.pyplot as plt

# 方法名
methods = ['128_hid', '256_hid', '512_hid', '1024_hid']

# 各种指标
precision = [0.928, 0.927, 0.938, 0.948]
recall = [0.883, 0.871, 0.882, 0.876]
f1_score = [0.905, 0.896, 0.909, 0.910]
avg = [0.905, 0.898, 0.910, 0.911]

# 绘图
plt.figure(figsize=(10, 6))
plt.plot(methods, precision, marker='o', label='Precision', color='blue')
plt.plot(methods, recall, marker='s', label='Recall', color='green')
plt.plot(methods, f1_score, marker='^', label='F1 Score', color='red')
plt.plot(methods, avg, marker='d', label='Avg', color='purple')

# 设置纵轴范围从0.8开始
plt.ylim(0.8, 1.0)

# 添加图例、标题和标签
plt.title('Ablation Study on Hidden Size')
plt.xlabel('Method')
plt.ylabel('Score')
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.savefig('Hidden_Size.jpg',dpi=300, bbox_inches='tight')
# 显示图像
plt.show()

# %%
import matplotlib.pyplot as plt

# 方法名
methods = [
    'MLP', 'LSTM', 'GCN', 'Skip-GCN', 'GAT', 'GATv2', 'BWGNN', 'Evolve-GCN',
    'Temporal-GCN', 'BT2(mean)', 'BT2(pool)', 'BT2(lstm)',
    'Inspection-L', 'Inspection-L(LF)', 'Inspection-L(AF)',
    'GAPLG(MLP)', 'GAPLG(GCN)', 'GAPLG(GAT)', 'POLICE(our)'
]

# 各种指标
precision = [
    0.637, 0.665, 0.812, 0.812, 0.842, 0.823, 0.748, 0.850,
    0.927, 0.850, 0.835, 0.859, 0.593, 0.906, 0.972,
    0.832, 0.861, 0.905, 0.948
]
recall = [
    0.662, 0.350, 0.512, 0.623, 0.554, 0.615, 0.509, 0.642,
    0.713, 0.713, 0.704, 0.755, 0.032, 0.712, 0.721,
    0.575, 0.587, 0.609, 0.876
]
f1_score = [
    0.629, 0.459, 0.628, 0.705, 0.668, 0.704, 0.606, 0.720,
    0.806, 0.760, 0.757, 0.802, 0.061, 0.797, 0.828,
    0.680, 0.698, 0.726, 0.910
]
avg = [
    0.643, 0.491, 0.651, 0.713, 0.689, 0.714, 0.621, 0.737,
    0.815, 0.774, 0.765, 0.805, 0.229, 0.806, 0.840,
    0.696, 0.715, 0.747, 0.911
]

# 设置图形
plt.figure(figsize=(14, 7))

# 画四条折线
plt.plot(methods, precision, marker='o', label='Precision', color='blue')
plt.plot(methods, recall, marker='s', label='Recall', color='green')
plt.plot(methods, f1_score, marker='^', label='F1 Score', color='red')
plt.plot(methods, avg, marker='d', label='Avg', color='purple')

# 设置纵轴范围
plt.ylim(0.0, 1.0)

# 旋转横轴标签以防重叠
plt.xticks(rotation=45, ha='right')

# 添加图例、标题和标签
plt.title('Model Comparison Results')
plt.xlabel('Method')
plt.ylabel('Score')
plt.grid(True)
plt.legend()
plt.tight_layout()


plt.savefig('Model_Comparison_Results.jpg',dpi=300, bbox_inches='tight')
# 显示图像
plt.show()

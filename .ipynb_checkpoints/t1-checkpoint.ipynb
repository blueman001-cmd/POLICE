# %%
import umap
print(umap.__file__)
print(dir(umap))  # 应该看到有 'UMAP
# Out:
# /root/miniconda3/lib/python3.10/site-packages/umap/__init__.py
# ['AlignedUMAP', 'PackageNotFoundError', 'ParametricUMAP', 'UMAP', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '__warningregistry__', 'aligned_umap', 'catch_warnings', 'distances', 'layouts', 'numba', 'simplefilter', 'sparse', 'spectral', 'umap_', 'utils', 'version', 'warn']

# %%
import pandas as pd

# 假设你读取了一个 CSV 文件：
df = pd.read_csv("dataset/elliptic_txs_features.csv")

# 查看某一列（比如 'column_name'）的不同值和每个值的数量：
print(df['1'].value_counts())
# Out:
# 1
# 1     7879
# 42    7140
# 5     6803
# 10    6727
# 3     6621
# 36    6393
# 7     6048
# 22    5894
# 4     5693
# 45    5598
# 35    5507
# 41    5342
# 47    5121
# 43    5063
# 9     4996
# 44    4975
# 24    4592
# 2     4544
# 13    4528
# 32    4525
# 40    4481
# 8     4457
# 6     4328
# 11    4296
# 20    4291
# 29    4275
# 23    4165
# 15    3639
# 21    3537
# 46    3519
# 19    3506
# 17    3385
# 37    3306
# 33    3151
# 16    2975
# 48    2954
# 38    2891
# 31    2816
# 39    2760
# 26    2523
# 34    2486
# 30    2483
# 49    2454
# 25    2314
# 12    2047
# 14    2022
# 18    1976
# 28    1653
# 27    1089
# Name: count, dtype: int64

# %%
import torch
print(torch.__version__)
# Out:
# 2.1.2+cu121

# %%
import pandas as pd
df =  pd.read_csv("dataset/elliptic_txs_classes.csv")
print("行数:", len(df))
print(df['class'].value_counts())
# print(df.head(20))
# print(df['txId'].dtype)
# print(3321 in df['txId'].values)
print(df[df['txId'] == 3321])
# print(11108 in df['txId'].values)
print(df[df['txId'] == 11108])
print(df[df['txId'] == 51816])
print(df[df['txId'] == 68869])
print(df[df['txId'] == 89273])
print(df[df['txId'] == 195142])
# Out:
# 行数: 203769
# class
# unknown    157205
# 2           42019
# 1            4545
# Name: count, dtype: int64
#       txId    class
# 2945  3321  unknown
#        txId    class
# 3188  11108  unknown
#        txId    class
# 2496  51816  unknown
#        txId class
# 4461  68869     2
#       txId class
# 130  89273     2
#         txId    class
# 3587  195142  unknown

# %%
import pandas as pd
df =  pd.read_csv("dataset/txs_classes.csv")
print("行数:", len(df))
print(df['class'].value_counts())
print(df.head(10))
# Out:
# 行数: 203769
# class
# 3    157205
# 2     42019
# 1      4545
# Name: count, dtype: int64
#      txId  class
# 0    3321      3
# 1   11108      3
# 2   51816      3
# 3   68869      2
# 4   89273      2
# 5  195142      3
# 6  223263      3
# 7  223265      3
# 8  245992      3
# 9  267260      3
